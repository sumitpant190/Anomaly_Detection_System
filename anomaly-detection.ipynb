# %% [markdown]
# # <center>Anomaly Detection</center>

# %%
# !python --version
# !jupyter notebook --version
# Out:
# Python 3.10.10
# 6.5.4

# %%
import tensorflow as tf
import keras
print(f"TensorFlow version: {tf.__version__}")
print(f"Keras version: {keras.__version__}")
# Out:
# TensorFlow version: 2.11.0
# Keras version: 2.11.0

# %%
#======================== using of training and testing and data augmetation with our model

# %%
#======================== using of training and testing and No augmetation with our model

# %%
from keras.preprocessing.image import ImageDataGenerator
import os
import cv2
import pickle
from tqdm import tqdm
import numpy as np
import random

test_dir = '/kaggle/input/ucf-crime-dataset/Test'
train_dir = '/kaggle/input/ucf-crime-dataset/Train'

# Define the categories and labels
categories_labels = {'Fighting': 0, 'Shoplifting': 1, 'Abuse': 2, 'Arrest': 3, 'Shooting': 4, 'Robbery': 5, 'Explosion': 6}

def load_data(base_dir, categories_labels):
    data = []
    
    # Go through each category
    for category, label in categories_labels.items():
        # The path to the category directory
        category_dir = os.path.join(base_dir, category)

        # Make sure the directory exists
        if os.path.isdir(category_dir):
            # Go through each file in the directory
            for filename in tqdm(os.listdir(category_dir), desc=f"Loading {category}"):
                # Make sure the file is an image
                if filename.endswith(".jpg") or filename.endswith(".png"):
                    # The path to the image
                    image_path = os.path.join(category_dir, filename)

                    try:
                        # Load the image
                        image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

                        # Resize the image
                        image = cv2.resize(image, (50, 50))

                        # Reshape the image to 4D array (ImageDataGenerator requires 4D array)
                        image = image.reshape((1,) + image.shape + (1,))

                        # Add the image and its label to the data
                        data.append([image, label])
                    except Exception as e:
                        print(f"Error loading image {image_path}: {e}")

    return data

# Load the training and test data
training_data = load_data(train_dir, categories_labels)
test_data = load_data(test_dir, categories_labels)

# Combine the training and test data
total_data = training_data + test_data

print(f"Loaded {len(total_data)} images.")
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Loading Fighting: 100%|██████████| 24684/24684 [03:25<00:00, 120.18it/s]
# Loading Shoplifting: 100%|██████████| 24835/24835 [03:28<00:00, 119.37it/s]
# Loading Abuse: 100%|██████████| 19076/19076 [02:38<00:00, 120.68it/s]
# Loading Arrest: 100%|██████████| 26397/26397 [03:38<00:00, 120.57it/s]
# Loading Shooting: 100%|██████████| 7140/7140 [01:00<00:00, 118.62it/s]
# Loading Robbery: 100%|██████████| 41493/41493 [05:42<00:00, 121.16it/s]
# Loading Explosion: 100%|██████████| 18753/18753 [02:31<00:00, 123.86it/s]
# Loading Fighting: 100%|██████████| 1231/1231 [00:07<00:00, 155.51it/s]
# Loading Shoplifting: 100%|██████████| 7623/7623 [01:00<00:00, 125.68it/s]
# Loading Abuse: 100%|██████████| 297/297 [00:01<00:00, 189.46it/s]
# Loading Arrest: 100%|██████████| 3365/3365 [00:24<00:00, 136.24it/s]
# Loading Shooting: 100%|██████████| 7630/7630 [01:01<00:00, 124.99it/s]
# Loading Robbery: 100%|██████████| 835/835 [00:05<00:00, 158.80it/s]
# Loading Explosion: 100%|██████████| 6510/6510 [00:51<00:00, 125.77it/s]
# Loaded 189869 images.

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from keras.utils import np_utils
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, LeakyReLU
from keras.layers import LSTM, TimeDistributed, Conv1D, MaxPooling1D
from keras.layers import Dense, Dropout, Flatten
from keras.layers import concatenate
from keras.utils.vis_utils import plot_model
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger
import time


# Initialize lists to store the images and the labels
images = []
labels = []

# Go through each image and its label in the total_data
for image, label in total_data:
    images.append(image)
    labels.append(label)

# Convert the lists into numpy arrays
images = np.array(images)
labels = np.array(labels)
print(images.shape)

# Reshape images for LSTM
images_lstm = images.reshape(images.shape[0], -1, 1)  # Added third dimension for features

# Set a seed for reproducibility
seed = 42

# Split the data into training and testing sets for CNN
train_images_cnn, test_images_cnn, train_labels_cnn, test_labels_cnn = train_test_split(images, labels, test_size=0.1, random_state=seed)

# Split the data into training and testing sets for LSTM
train_images_lstm, test_images_lstm, train_labels_lstm, test_labels_lstm = train_test_split(images_lstm, labels, test_size=0.1, random_state=seed)

# Convert labels to categorical for CNN
train_labels_cnn = np_utils.to_categorical(train_labels_cnn, len(categories_labels))
test_labels_cnn = np_utils.to_categorical(test_labels_cnn, len(categories_labels))

# Convert labels to categorical for LSTM
train_labels_lstm = np_utils.to_categorical(train_labels_lstm, len(categories_labels))
test_labels_lstm = np_utils.to_categorical(test_labels_lstm, len(categories_labels))

# Remove the second dimension from your data
train_images_cnn = np.squeeze(train_images_cnn, axis=1)
test_images_cnn = np.squeeze(test_images_cnn, axis=1)


# CNN Model
model_CNN = Sequential()
model_CNN.add(Conv2D(64, kernel_size=(3, 3), padding='same', input_shape=(50, 50, 1)))
model_CNN.add(LeakyReLU(alpha=0.1)) 
model_CNN.add(MaxPooling2D((2, 2), padding='same')) 
model_CNN.add(Dropout(0.25))
model_CNN.add(Conv2D(128, (3, 3), padding='same')) 
model_CNN.add(LeakyReLU(alpha=0.1)) 
model_CNN.add(MaxPooling2D(pool_size=(2, 2), padding='same')) 
model_CNN.add(Dropout(0.25))
model_CNN.add(Conv2D(256, (3, 3), padding='same'))
model_CNN.add(LeakyReLU(alpha=0.1))
model_CNN.add(MaxPooling2D(pool_size=(2, 2), padding='same')) 
model_CNN.add(Dropout(0.4))  
model_CNN.add(Flatten()) 
model_CNN.add(Dense(256)) 
model_CNN.add(LeakyReLU(alpha=0.1))            
model_CNN.add(Dropout(0.5)) 

# LSTM Model
model_lstm = Sequential()
model_lstm.add(LSTM(units = 8, return_sequences = True, input_shape = (2500, 1), activation='tanh'))
model_lstm.add(LSTM(units = 8, return_sequences = True))
model_lstm.add(Dense(4, activation='tanh'))
model_lstm.add(Dropout(0.2))
model_lstm.add(Flatten())

# Combine CNN and LSTM model
nb_classes = 7
combined = concatenate([model_CNN.output, model_lstm.output], axis=-1)
output = Dense(nb_classes, activation='softmax')(combined)
model_final = Model(inputs=[model_CNN.input, model_lstm.input], outputs=output)

# Plot and compile the model
plot_model(model_final, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

model_final.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Callbacks
csv_logger = CSVLogger('training.log', separator=',', append=False)
mc = ModelCheckpoint('CNN_LSTM.h5', monitor='val_loss', mode='min', verbose=1, save_best_only=True)

# Training
time1 = time.time()
history = model_final.fit([train_images_cnn, train_images_lstm], train_labels_lstm, batch_size=1000, epochs=20, validation_data=([test_images_cnn, test_images_lstm], test_labels_lstm), callbacks=[mc, csv_logger])
print (("Training time=", time.time()-time1))

# Save training history
np.save("CNN_LSTM_history.npy", history.history)
# Out:
# (189869, 1, 50, 50, 1)
# Epoch 1/20
# 2024-07-14 06:34:10.060868: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 171/171 [==============================] - ETA: 0s - loss: 1.7819 - accuracy: 0.5493
# Epoch 1: val_loss improved from inf to 5.70274, saving model to CNN_LSTM.h5
# 171/171 [==============================] - 149s 806ms/step - loss: 1.7819 - accuracy: 0.5493 - val_loss: 5.7027 - val_accuracy: 0.4639
# Epoch 2/20
# 171/171 [==============================] - ETA: 0s - loss: 0.3894 - accuracy: 0.8793
# Epoch 2: val_loss improved from 5.70274 to 2.25442, saving model to CNN_LSTM.h5
# 171/171 [==============================] - 136s 796ms/step - loss: 0.3894 - accuracy: 0.8793 - val_loss: 2.2544 - val_accuracy: 0.6837
# Epoch 3/20
# 171/171 [==============================] - ETA: 0s - loss: 0.1399 - accuracy: 0.9589
# Epoch 3: val_loss improved from 2.25442 to 0.68502, saving model to CNN_LSTM.h5
# 171/171 [==============================] - 137s 802ms/step - loss: 0.1399 - accuracy: 0.9589 - val_loss: 0.6850 - val_accuracy: 0.8365
# Epoch 4/20
# 171/171 [==============================] - ETA: 0s - loss: 0.0746 - accuracy: 0.9783
# Epoch 4: val_loss improved from 0.68502 to 0.11795, saving model to CNN_LSTM.h5
# 171/171 [==============================] - 136s 796ms/step - loss: 0.0746 - accuracy: 0.9783 - val_loss: 0.1179 - val_accuracy: 0.9639
# Epoch 5/20
# 171/171 [==============================] - ETA: 0s - loss: 0.0507 - accuracy: 0.9846
# Epoch 5: val_loss improved from 0.11795 to 0.04404, saving model to CNN_LSTM.h5
# 171/171 [==============================] - 136s 796ms/step - loss: 0.0507 - accuracy: 0.9846 - val_loss: 0.0440 - val_accuracy: 0.9870
# Epoch 6/20
# 171/171 [==============================] - ETA: 0s - loss: 0.0361 - accuracy: 0.9888
# Epoch 6: val_loss improved from 0.04404 to 0.04056, saving model to CNN_LSTM.h5
# 171/171 [==============================] - 136s 797ms/step - loss: 0.0361 - accuracy: 0.9888 - val_loss: 0.0406 - val_accuracy: 0.9868
# Epoch 7/20
# 171/171 [==============================] - ETA: 0s - loss: 0.0289 - accuracy: 0.9907
# Epoch 7: val_loss did not improve from 0.04056
# 171/171 [==============================] - 136s 795ms/step - loss: 0.0289 - accuracy: 0.9907 - val_loss: 0.0450 - val_accuracy: 0.9877
# Epoch 8/20
# 171/171 [==============================] - ETA: 0s - loss: 0.0247 - accuracy: 0.9923
# Epoch 8: val_loss improved from 0.04056 to 0.01766, saving model to CNN_LSTM.h5
# 171/171 [==============================] - 136s 797ms/step - loss: 0.0247 - accuracy: 0.9923 - val_loss: 0.0177 - val_accuracy: 0.9944
# Epoch 9/20
# 171/171 [==============================] - ETA: 0s - loss: 0.0220 - accuracy: 0.9929
# Epoch 9: val_loss improved from 0.01766 to 0.01206, saving model to CNN_LSTM.h5
# 171/171 [==============================] - 137s 801ms/step - loss: 0.0220 - accuracy: 0.9929 - val_loss: 0.0121 - val_accuracy: 0.9959
# Epoch 10/20
# 171/171 [==============================] - ETA: 0s - loss: 0.0189 - accuracy: 0.9938
# Epoch 10: val_loss did not improve from 0.01206
# 171/171 [==============================] - 136s 795ms/step - loss: 0.0189 - accuracy: 0.9938 - val_loss: 0.0164 - val_accuracy: 0.9944
# Epoch 11/20
# 171/171 [==============================] - ETA: 0s - loss: 0.0188 - accuracy: 0.9937
# Epoch 11: val_loss improved from 0.01206 to 0.01029, saving model to CNN_LSTM.h5
# 171/171 [==============================] - 136s 795ms/step - loss: 0.0188 - accuracy: 0.9937 - val_loss: 0.0103 - val_accuracy: 0.9960
# Epoch 12/20
# 171/171 [==============================] - ETA: 0s - loss: 0.0167 - accuracy: 0.9944
# Epoch 12: val_loss did not improve from 0.01029
# 171/171 [==============================] - 136s 796ms/step - loss: 0.0167 - accuracy: 0.9944 - val_loss: 0.0110 - val_accuracy: 0.9965
# Epoch 13/20
# 171/171 [==============================] - ETA: 0s - loss: 0.0160 - accuracy: 0.9947
# Epoch 13: val_loss improved from 0.01029 to 0.00977, saving model to CNN_LSTM.h5
# 171/171 [==============================] - 136s 796ms/step - loss: 0.0160 - accuracy: 0.9947 - val_loss: 0.0098 - val_accuracy: 0.9966
# Epoch 14/20
# 171/171 [==============================] - ETA: 0s - loss: 0.0156 - accuracy: 0.9948
# Epoch 14: val_loss improved from 0.00977 to 0.00893, saving model to CNN_LSTM.h5
# 171/171 [==============================] - 136s 797ms/step - loss: 0.0156 - accuracy: 0.9948 - val_loss: 0.0089 - val_accuracy: 0.9966
# Epoch 15/20
# 171/171 [==============================] - ETA: 0s - loss: 0.0154 - accuracy: 0.9949
# Epoch 15: val_loss did not improve from 0.00893
# 171/171 [==============================] - 136s 798ms/step - loss: 0.0154 - accuracy: 0.9949 - val_loss: 0.0098 - val_accuracy: 0.9965
# Epoch 16/20
# 171/171 [==============================] - ETA: 0s - loss: 0.0151 - accuracy: 0.9951
# Epoch 16: val_loss did not improve from 0.00893
# 171/171 [==============================] - 136s 794ms/step - loss: 0.0151 - accuracy: 0.9951 - val_loss: 0.0103 - val_accuracy: 0.9966
# Epoch 17/20
# 171/171 [==============================] - ETA: 0s - loss: 0.0142 - accuracy: 0.9953
# Epoch 17: val_loss improved from 0.00893 to 0.00867, saving model to CNN_LSTM.h5
# 171/171 [==============================] - 136s 796ms/step - loss: 0.0142 - accuracy: 0.9953 - val_loss: 0.0087 - val_accuracy: 0.9968
# Epoch 18/20
# 171/171 [==============================] - ETA: 0s - loss: 0.0139 - accuracy: 0.9954
# Epoch 18: val_loss did not improve from 0.00867
# 171/171 [==============================] - 136s 795ms/step - loss: 0.0139 - accuracy: 0.9954 - val_loss: 0.0106 - val_accuracy: 0.9966
# Epoch 19/20
# 171/171 [==============================] - ETA: 0s - loss: 0.0139 - accuracy: 0.9955
# Epoch 19: val_loss did not improve from 0.00867
# 171/171 [==============================] - 136s 794ms/step - loss: 0.0139 - accuracy: 0.9955 - val_loss: 0.0124 - val_accuracy: 0.9963
# Epoch 20/20
# 171/171 [==============================] - ETA: 0s - loss: 0.0126 - accuracy: 0.9958
# Epoch 20: val_loss did not improve from 0.00867
# 171/171 [==============================] - 136s 795ms/step - loss: 0.0126 - accuracy: 0.9958 - val_loss: 0.0090 - val_accuracy: 0.9965
# ('Training time=', 2738.0620725154877)

# %%
from keras.models import load_model
fashion_model = load_model('./CNN_LSTM.h5') # load model
fashion_model.summary() # summarize model.

from contextlib import redirect_stdout
with open('./CNN_LSTM'+".xls", 'w') as f:
    with redirect_stdout(f):
        fashion_model.summary()
        
val_loss, val_accuracy=fashion_model.evaluate([test_images_cnn, test_images_lstm] ,test_labels_cnn) ## to get test accuracy and losses
print(val_loss, val_accuracy)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  conv2d_input (InputLayer)      [(None, 50, 50, 1)]  0           []
#
#  conv2d (Conv2D)                (None, 50, 50, 64)   640         ['conv2d_input[0][0]']
#
#  leaky_re_lu (LeakyReLU)        (None, 50, 50, 64)   0           ['conv2d[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 25, 25, 64)   0           ['leaky_re_lu[0][0]']
#
#  dropout (Dropout)              (None, 25, 25, 64)   0           ['max_pooling2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 25, 25, 128)  73856       ['dropout[0][0]']
#
#  leaky_re_lu_1 (LeakyReLU)      (None, 25, 25, 128)  0           ['conv2d_1[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 13, 13, 128)  0          ['leaky_re_lu_1[0][0]']
#
#  dropout_1 (Dropout)            (None, 13, 13, 128)  0           ['max_pooling2d_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 13, 13, 256)  295168      ['dropout_1[0][0]']
#
#  leaky_re_lu_2 (LeakyReLU)      (None, 13, 13, 256)  0           ['conv2d_2[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 7, 7, 256)   0           ['leaky_re_lu_2[0][0]']
#
#  lstm_input (InputLayer)        [(None, 2500, 1)]    0           []
#
#  dropout_2 (Dropout)            (None, 7, 7, 256)    0           ['max_pooling2d_2[0][0]']
#
#  lstm (LSTM)                    (None, 2500, 8)      320         ['lstm_input[0][0]']
#
#  flatten (Flatten)              (None, 12544)        0           ['dropout_2[0][0]']
#
#  lstm_1 (LSTM)                  (None, 2500, 8)      544         ['lstm[0][0]']
#
#  dense (Dense)                  (None, 256)          3211520     ['flatten[0][0]']
#
#  dense_1 (Dense)                (None, 2500, 4)      36          ['lstm_1[0][0]']
#
#  leaky_re_lu_3 (LeakyReLU)      (None, 256)          0           ['dense[0][0]']
#
#  dropout_4 (Dropout)            (None, 2500, 4)      0           ['dense_1[0][0]']
#
#  dropout_3 (Dropout)            (None, 256)          0           ['leaky_re_lu_3[0][0]']
#
#  flatten_1 (Flatten)            (None, 10000)        0           ['dropout_4[0][0]']
#
#  concatenate (Concatenate)      (None, 10256)        0           ['dropout_3[0][0]',
#                                                                   'flatten_1[0][0]']
#
#  dense_2 (Dense)                (None, 7)            71799       ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 3,653,883
# Trainable params: 3,653,883
# Non-trainable params: 0
# __________________________________________________________________________________________________
# 594/594 [==============================] - 34s 55ms/step - loss: 0.0087 - accuracy: 0.9968
# 0.008667505346238613 0.9968399405479431

# %%
time2=time.time()
predict_prob=fashion_model.predict([test_images_cnn, test_images_lstm])
y_pred=np.argmax(predict_prob,axis=1)
print ('classification time:', time.time()-time2)

##print (y_pred)
y_true=np.argmax(test_labels_cnn, axis=1)
from sklearn.metrics import precision_recall_fscore_support as score, precision_score, recall_score, f1_score
from sklearn.metrics import classification_report, confusion_matrix
cm = confusion_matrix(y_true, y_pred)
print (cm)
print(classification_report(y_true, y_pred))

precision = precision_score(y_true, y_pred, average='weighted')
print('Precision: %f' % precision)
# recall: tp / (tp + fn)
recall = recall_score(y_true, y_pred, average='weighted')
print('Recall: %f' % recall)
# f1: tp / (tp + fp + fn)
f1 = f1_score(y_true, y_pred, average='weighted')
print('F1 score: %f' % f1)
#-----------  IoU
from sklearn.metrics import jaccard_score
print ('IoU:', jaccard_score(y_true, y_pred, average='micro'))


test_eval = fashion_model.evaluate([test_images_cnn, test_images_lstm], test_labels_cnn)

loss, accuracy = fashion_model.evaluate([train_images_cnn, train_images_lstm], train_labels_cnn)
print('loss_train: ', loss, 'accuracy_train: ', accuracy)
print('Test loss:', test_eval[0], 'Test accuracy:', test_eval[1])
# Out:
# 594/594 [==============================] - 33s 54ms/step
# classification time: 33.371659994125366
# [[2531    0    0    1    0    0    0]
#  [   0 3306    0    2    0    1    1]
#  [   1    0 1956    1    2    0    2]
#  [   0    3    1 2993    4    1    0]
#  [   3    0    1   17 1438    0    0]
#  [   5    1    0    0    0 4123    3]
#  [   2    0    1    1    1    5 2580]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2532
#            1       1.00      1.00      1.00      3310
#            2       1.00      1.00      1.00      1962
#            3       0.99      1.00      0.99      3002
#            4       1.00      0.99      0.99      1459
#            5       1.00      1.00      1.00      4132
#            6       1.00      1.00      1.00      2590
#
#     accuracy                           1.00     18987
#    macro avg       1.00      1.00      1.00     18987
# weighted avg       1.00      1.00      1.00     18987
#
# Precision: 0.996843
# Recall: 0.996840
# F1 score: 0.996838
# IoU: 0.9936997952433454
# 594/594 [==============================] - 33s 55ms/step - loss: 0.0087 - accuracy: 0.9968
# 5341/5341 [==============================] - 297s 56ms/step - loss: 0.0060 - accuracy: 0.9978
# loss_train:  0.005958851892501116 accuracy_train:  0.997758686542511
# Test loss: 0.008667505346238613 Test accuracy: 0.9968399405479431

# %%
import matplotlib.pyplot as plt

history_dict=history.history
loss_values=history_dict['loss']
val_loss_values=history_dict['val_loss']
acc_values=history_dict['accuracy']
val_acc_values=history_dict['val_accuracy']
epochs=range(1, len(acc_values)+1)
def smooth_curve(points, factor=0.8):
    smoothed_points = []
    for point in points:
        if smoothed_points:
            previous = smoothed_points[-1]
            smoothed_points.append(previous * factor + point * (1 - factor))
        else:
            smoothed_points.append(point)
    return smoothed_points
loss_values=smooth_curve(loss_values)
val_loss_values=smooth_curve(val_loss_values)
acc_values=smooth_curve(acc_values)
val_acc_values=smooth_curve(val_acc_values)

font = {'family' : 'serif',
        'color'  : 'black',
        'weight' : 'normal',
        'size'   : 12}
        

plt.plot(epochs, acc_values, 'r-', label='Training acc')
plt.plot(epochs, val_acc_values, 'g', label='Validation acc')
plt.title('Training and Validation acc', fontdict=font)
plt.xlabel('Epochs', fontdict=font)
plt.ylabel('Accuracy', fontdict=font)
plt.legend()
plt.savefig("accuracy"+'CNN_LSTM'+".png")
plt.show()

plt.plot(epochs, loss_values, 'b-', label='Training loss')
plt.plot(epochs, val_loss_values, 'r', label='Validation loss')
plt.title('Training and Validation loss', fontdict=font)
plt.xlabel('Epochs',fontdict=font)
plt.ylabel('Loss',fontdict=font)
plt.legend()
plt.savefig("loss"+'CNN_LSTM'+".png")
plt.show()

# %%
class_names = ['Fighting', 'Shoplifting', 'Abuse', 'Arrest', 'Shooting', 'Robbery', 'Explosion']


def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
#    classes = classes[unique_labels(y_true, y_pred)]
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    fig, ax = plt.subplots(figsize=(10, 10))
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return ax

font = {'family' : 'serif',
        'color'  : 'black',
        'weight' : 'normal',
        'size'   : 14}

np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plot_confusion_matrix(y_true, y_pred, classes=class_names,
                      title='Confusion matrix, without normalization')
plt.savefig('confusion matrix1'+'CNN_LSTM'+'.png')
plt.show()
# Plot normalized confusion matrix
plot_confusion_matrix(y_true, y_pred, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')
plt.savefig('confusion matrix2'+'CNN_LSTM'+'.png')
plt.show()
# Out:
# Confusion matrix, without normalization
# [[2531    0    0    1    0    0    0]
#  [   0 3306    0    2    0    1    1]
#  [   1    0 1956    1    2    0    2]
#  [   0    3    1 2993    4    1    0]
#  [   3    0    1   17 1438    0    0]
#  [   5    1    0    0    0 4123    3]
#  [   2    0    1    1    1    5 2580]]
# Normalized confusion matrix
# [[1.00e+00 0.00e+00 0.00e+00 3.95e-04 0.00e+00 0.00e+00 0.00e+00]
#  [0.00e+00 9.99e-01 0.00e+00 6.04e-04 0.00e+00 3.02e-04 3.02e-04]
#  [5.10e-04 0.00e+00 9.97e-01 5.10e-04 1.02e-03 0.00e+00 1.02e-03]
#  [0.00e+00 9.99e-04 3.33e-04 9.97e-01 1.33e-03 3.33e-04 0.00e+00]
#  [2.06e-03 0.00e+00 6.85e-04 1.17e-02 9.86e-01 0.00e+00 0.00e+00]
#  [1.21e-03 2.42e-04 0.00e+00 0.00e+00 0.00e+00 9.98e-01 7.26e-04]
#  [7.72e-04 0.00e+00 3.86e-04 3.86e-04 3.86e-04 1.93e-03 9.96e-01]]

# %%
import cv2
import numpy as np
from keras.models import load_model

# Define your categories and labels
categories_labels = {'Fighting': 0, 'Shoplifting': 1, 'Abuse': 2, 'Arrest': 3, 'Shooting': 4, 'Robbery': 5, 'Explosion': 6}
labels_categories = {v: k for k, v in categories_labels.items()}  # reverse dictionary for label lookup
num_classes = len(categories_labels)

# Load the trained model
model = load_model('/kaggle/input/model2/CNN_LSTM (1).h5')

def predict_image(image):
    # Resize the image
    image = cv2.resize(image, (50, 50))

    # Convert to grayscale
    image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Reshape the image to 4D array for CNN and LSTM input
    image_cnn = image_gray.reshape((1,) + image_gray.shape + (1,))
    image_lstm = image_gray.reshape((1,) + (-1, 1))

    # Use the model to predict the category of the image
    prediction = model.predict([image_cnn, image_lstm])

    # Extract probabilities for each class
    probabilities = prediction[0]

    # Find the category with the highest probability
    predicted_label_index = np.argmax(probabilities)
    predicted_label = labels_categories[predicted_label_index]

    # Return the predicted label
    return predicted_label

# Function to process video and show frames with changing predictions
def process_video(video_path):
    cap = cv2.VideoCapture(video_path)
    frame_count = 0
    prev_prediction = None
    
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        
        frame_count += 1
        
        # Predict action for this frame
        current_prediction = predict_image(frame)
        
        # Compare with previous prediction
        if prev_prediction is None or current_prediction != prev_prediction:
            # Display or save results as needed
            print(f"Frame {frame_count}: Predicted Label: {current_prediction}")
            print("--------------------")
        
        # Update previous prediction
        prev_prediction = current_prediction
    
    cap.release()

# Replace with your video file path
video_path = "/kaggle/input/video-test/Boxer Caught on CCTV - Knocks out 3 Men  Street Fight Self Defence Knockout Study.mp4"
process_video(video_path)
# Out:
# 1/1 [==============================] - 1s 1s/step
# Frame 1: Predicted Label: Shoplifting
# --------------------
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 206ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 205ms/step
# 1/1 [==============================] - 0s 200ms/step
# 1/1 [==============================] - 0s 217ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 186ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 180ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 210ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 208ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 183ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 179ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 199ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 209ms/step
# 1/1 [==============================] - 0s 195ms/step
# 1/1 [==============================] - 0s 242ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 193ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 174ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 177ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 166ms/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 66
#      64 # Replace with your video file path
#      65 video_path = "/kaggle/input/video-test/Boxer Caught on CCTV - Knocks out 3 Men  Street Fight Self Defence Knockout Study.mp4"
# ---> 66 process_video(video_path)
#
# Cell In[4], line 51, in process_video(video_path)
#      48 frame_count += 1
#      50 # Predict action for this frame
# ---> 51 current_prediction = predict_image(frame)
#      53 # Compare with previous prediction
#      54 if prev_prediction is None or current_prediction != prev_prediction:
#      55     # Display or save results as needed
#
# Cell In[4], line 25, in predict_image(image)
#      22 image_lstm = image_gray.reshape((1,) + (-1, 1))
#      24 # Use the model to predict the category of the image
# ---> 25 prediction = model.predict([image_cnn, image_lstm])
#      27 # Extract probabilities for each class
#      28 probabilities = prediction[0]
#
# File /opt/conda/lib/python3.10/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# KeyboardInterrupt:

# %%
import cv2
import numpy as np
from keras.models import load_model

# Define your categories and labels
categories_labels = {'Fighting': 0, 'Shoplifting': 1, 'Abuse': 2, 'Arrest': 3, 'Shooting': 4, 'Robbery': 5, 'Explosion': 6}
labels_categories = {v: k for k, v in categories_labels.items()}  # reverse dictionary for label lookup
num_classes = len(categories_labels)

# Load the trained model
model = load_model('/kaggle/input/model2/CNN_LSTM (1).h5')

def predict_image(image):
    # Resize the image
    image = cv2.resize(image, (50, 50))

    # Convert to grayscale
    image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Reshape the image to 4D array for CNN and LSTM input
    image_cnn = image_gray.reshape((1,) + image_gray.shape + (1,))
    image_lstm = image_gray.reshape((1,) + (-1, 1))

    # Use the model to predict the category of the image
    prediction = model.predict([image_cnn, image_lstm])

    # Extract probabilities for each class
    probabilities = prediction[0]

    # Find the category with the highest probability
    predicted_label_index = np.argmax(probabilities)
    predicted_label = labels_categories[predicted_label_index]

    # Return the predicted label and probabilities for each class
    return predicted_label, probabilities

# Function to process video and predict on each frame
def process_video(video_path):
    cap = cv2.VideoCapture(video_path)
    frame_count = 0
    
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        
        frame_count += 1
        
        # Process every other frame (adjust as needed)
        if frame_count % 2 == 0:
            # Predict action for this frame
            predicted_label, probabilities = predict_image(frame)
            
            # Display or save results as needed
            print(f"Frame {frame_count}: Predicted Label: {predicted_label}")
            print("Probabilities:")
            for category, prob in zip(categories_labels.keys(), probabilities):
                print(f"{category}: {prob:.4f}")
            print("--------------------")
    
    cap.release()

# Replace with your video file path
video_path = "/kaggle/input/video-test/Boxer Caught on CCTV - Knocks out 3 Men  Street Fight Self Defence Knockout Study.mp4"
process_video(video_path)
# Out:
# 1/1 [==============================] - 1s 967ms/step
# Frame 2: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0019
# Shoplifting: 0.9974
# Abuse: 0.0000
# Arrest: 0.0007
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 167ms/step
# Frame 4: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0016
# Shoplifting: 0.9975
# Abuse: 0.0000
# Arrest: 0.0009
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 168ms/step
# Frame 6: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0017
# Shoplifting: 0.9977
# Abuse: 0.0000
# Arrest: 0.0006
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 164ms/step
# Frame 8: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0015
# Shoplifting: 0.9980
# Abuse: 0.0000
# Arrest: 0.0005
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 168ms/step
# Frame 10: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0011
# Shoplifting: 0.9985
# Abuse: 0.0000
# Arrest: 0.0004
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 167ms/step
# Frame 12: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0011
# Shoplifting: 0.9985
# Abuse: 0.0000
# Arrest: 0.0003
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 171ms/step
# Frame 14: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0007
# Shoplifting: 0.9990
# Abuse: 0.0000
# Arrest: 0.0002
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 173ms/step
# Frame 16: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0010
# Shoplifting: 0.9987
# Abuse: 0.0000
# Arrest: 0.0003
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 183ms/step
# Frame 18: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0009
# Shoplifting: 0.9988
# Abuse: 0.0000
# Arrest: 0.0003
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 167ms/step
# Frame 20: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0009
# Shoplifting: 0.9988
# Abuse: 0.0000
# Arrest: 0.0003
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 167ms/step
# Frame 22: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0008
# Shoplifting: 0.9989
# Abuse: 0.0000
# Arrest: 0.0003
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 168ms/step
# Frame 24: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0007
# Shoplifting: 0.9990
# Abuse: 0.0000
# Arrest: 0.0003
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 169ms/step
# Frame 26: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0009
# Shoplifting: 0.9988
# Abuse: 0.0000
# Arrest: 0.0003
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 169ms/step
# Frame 28: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0011
# Shoplifting: 0.9985
# Abuse: 0.0000
# Arrest: 0.0004
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 169ms/step
# Frame 30: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0011
# Shoplifting: 0.9986
# Abuse: 0.0000
# Arrest: 0.0004
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 167ms/step
# Frame 32: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0010
# Shoplifting: 0.9987
# Abuse: 0.0000
# Arrest: 0.0003
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 165ms/step
# Frame 34: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0008
# Shoplifting: 0.9989
# Abuse: 0.0000
# Arrest: 0.0003
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 168ms/step
# Frame 36: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0007
# Shoplifting: 0.9990
# Abuse: 0.0000
# Arrest: 0.0003
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 165ms/step
# Frame 38: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0007
# Shoplifting: 0.9990
# Abuse: 0.0000
# Arrest: 0.0003
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 164ms/step
# Frame 40: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0008
# Shoplifting: 0.9989
# Abuse: 0.0000
# Arrest: 0.0003
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 169ms/step
# Frame 42: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0007
# Shoplifting: 0.9991
# Abuse: 0.0000
# Arrest: 0.0003
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 168ms/step
# Frame 44: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0006
# Shoplifting: 0.9992
# Abuse: 0.0000
# Arrest: 0.0002
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 168ms/step
# Frame 46: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0004
# Shoplifting: 0.9994
# Abuse: 0.0000
# Arrest: 0.0002
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 167ms/step
# Frame 48: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0004
# Shoplifting: 0.9995
# Abuse: 0.0000
# Arrest: 0.0002
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 167ms/step
# Frame 50: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0004
# Shoplifting: 0.9994
# Abuse: 0.0000
# Arrest: 0.0002
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 170ms/step
# Frame 52: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0006
# Shoplifting: 0.9992
# Abuse: 0.0000
# Arrest: 0.0002
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 174ms/step
# Frame 54: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0008
# Shoplifting: 0.9990
# Abuse: 0.0000
# Arrest: 0.0002
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 168ms/step
# Frame 56: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0007
# Shoplifting: 0.9991
# Abuse: 0.0000
# Arrest: 0.0002
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 171ms/step
# Frame 58: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0007
# Shoplifting: 0.9992
# Abuse: 0.0000
# Arrest: 0.0002
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 171ms/step
# Frame 60: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0007
# Shoplifting: 0.9992
# Abuse: 0.0000
# Arrest: 0.0002
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 172ms/step
# Frame 62: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0005
# Shoplifting: 0.9993
# Abuse: 0.0000
# Arrest: 0.0001
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 170ms/step
# Frame 64: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0005
# Shoplifting: 0.9993
# Abuse: 0.0000
# Arrest: 0.0001
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 169ms/step
# Frame 66: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0005
# Shoplifting: 0.9993
# Abuse: 0.0000
# Arrest: 0.0001
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 168ms/step
# Frame 68: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0005
# Shoplifting: 0.9994
# Abuse: 0.0000
# Arrest: 0.0001
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 168ms/step
# Frame 70: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0004
# Shoplifting: 0.9995
# Abuse: 0.0000
# Arrest: 0.0001
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 167ms/step
# Frame 72: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0004
# Shoplifting: 0.9995
# Abuse: 0.0000
# Arrest: 0.0001
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 176ms/step
# Frame 74: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0004
# Shoplifting: 0.9996
# Abuse: 0.0000
# Arrest: 0.0001
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 190ms/step
# Frame 76: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0003
# Shoplifting: 0.9996
# Abuse: 0.0000
# Arrest: 0.0001
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 178ms/step
# Frame 78: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0003
# Shoplifting: 0.9997
# Abuse: 0.0000
# Arrest: 0.0001
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 176ms/step
# Frame 80: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0003
# Shoplifting: 0.9997
# Abuse: 0.0000
# Arrest: 0.0001
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 178ms/step
# Frame 82: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0002
# Shoplifting: 0.9997
# Abuse: 0.0000
# Arrest: 0.0001
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 169ms/step
# Frame 84: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0002
# Shoplifting: 0.9997
# Abuse: 0.0000
# Arrest: 0.0001
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 168ms/step
# Frame 86: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0002
# Shoplifting: 0.9997
# Abuse: 0.0000
# Arrest: 0.0001
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 171ms/step
# Frame 88: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0003
# Shoplifting: 0.9996
# Abuse: 0.0000
# Arrest: 0.0001
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 169ms/step
# Frame 90: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0002
# Shoplifting: 0.9997
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 170ms/step
# Frame 92: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0003
# Shoplifting: 0.9996
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 168ms/step
# Frame 94: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0003
# Shoplifting: 0.9997
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 167ms/step
# Frame 96: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0002
# Shoplifting: 0.9997
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 170ms/step
# Frame 98: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0002
# Shoplifting: 0.9998
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 167ms/step
# Frame 100: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0001
# Shoplifting: 0.9999
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 167ms/step
# Frame 102: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0001
# Shoplifting: 0.9998
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 167ms/step
# Frame 104: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0001
# Shoplifting: 0.9998
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 172ms/step
# Frame 106: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0002
# Shoplifting: 0.9998
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 174ms/step
# Frame 108: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0002
# Shoplifting: 0.9998
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 187ms/step
# Frame 110: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0002
# Shoplifting: 0.9998
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 166ms/step
# Frame 112: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0001
# Shoplifting: 0.9999
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 164ms/step
# Frame 114: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0001
# Shoplifting: 0.9999
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 168ms/step
# Frame 116: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0001
# Shoplifting: 0.9999
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 168ms/step
# Frame 118: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0001
# Shoplifting: 0.9999
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 169ms/step
# Frame 120: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0001
# Shoplifting: 0.9999
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 164ms/step
# Frame 122: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0001
# Shoplifting: 0.9999
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 169ms/step
# Frame 124: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0001
# Shoplifting: 0.9999
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 172ms/step
# Frame 126: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0001
# Shoplifting: 0.9999
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 169ms/step
# Frame 128: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0001
# Shoplifting: 0.9999
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 165ms/step
# Frame 130: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0001
# Shoplifting: 0.9999
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 168ms/step
# Frame 132: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0001
# Shoplifting: 0.9998
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 167ms/step
# Frame 134: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0001
# Shoplifting: 0.9998
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 170ms/step
# Frame 136: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0002
# Shoplifting: 0.9998
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 169ms/step
# Frame 138: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0002
# Shoplifting: 0.9998
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 171ms/step
# Frame 140: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0002
# Shoplifting: 0.9998
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 168ms/step
# Frame 142: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0003
# Shoplifting: 0.9997
# Abuse: 0.0000
# Arrest: 0.0001
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 169ms/step
# Frame 144: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0003
# Shoplifting: 0.9997
# Abuse: 0.0000
# Arrest: 0.0001
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 168ms/step
# Frame 146: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0003
# Shoplifting: 0.9997
# Abuse: 0.0000
# Arrest: 0.0001
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 167ms/step
# Frame 148: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0003
# Shoplifting: 0.9997
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 166ms/step
# Frame 150: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0003
# Shoplifting: 0.9996
# Abuse: 0.0000
# Arrest: 0.0001
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 165ms/step
# Frame 152: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0004
# Shoplifting: 0.9996
# Abuse: 0.0000
# Arrest: 0.0001
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 168ms/step
# Frame 154: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0004
# Shoplifting: 0.9995
# Abuse: 0.0000
# Arrest: 0.0001
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 169ms/step
# Frame 156: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0005
# Shoplifting: 0.9995
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 169ms/step
# Frame 158: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0005
# Shoplifting: 0.9995
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 166ms/step
# Frame 160: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0006
# Shoplifting: 0.9993
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 165ms/step
# Frame 162: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0012
# Shoplifting: 0.9987
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 170ms/step
# Frame 164: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0013
# Shoplifting: 0.9986
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 169ms/step
# Frame 166: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0013
# Shoplifting: 0.9987
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 167ms/step
# Frame 168: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0013
# Shoplifting: 0.9987
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 167ms/step
# Frame 170: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0012
# Shoplifting: 0.9987
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 169ms/step
# Frame 172: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0012
# Shoplifting: 0.9987
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 170ms/step
# Frame 174: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0011
# Shoplifting: 0.9989
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 166ms/step
# Frame 176: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0010
# Shoplifting: 0.9990
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 169ms/step
# Frame 178: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0012
# Shoplifting: 0.9987
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 167ms/step
# Frame 180: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0013
# Shoplifting: 0.9986
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 171ms/step
# Frame 182: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0019
# Shoplifting: 0.9981
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 168ms/step
# Frame 184: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0026
# Shoplifting: 0.9974
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 168ms/step
# Frame 186: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0020
# Shoplifting: 0.9979
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 170ms/step
# Frame 188: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0019
# Shoplifting: 0.9980
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 171ms/step
# Frame 190: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0016
# Shoplifting: 0.9984
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 170ms/step
# Frame 192: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0014
# Shoplifting: 0.9986
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 172ms/step
# Frame 194: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0013
# Shoplifting: 0.9986
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 168ms/step
# Frame 196: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0012
# Shoplifting: 0.9988
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 167ms/step
# Frame 198: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0010
# Shoplifting: 0.9990
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 176ms/step
# Frame 200: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0007
# Shoplifting: 0.9993
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 191ms/step
# Frame 202: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0006
# Shoplifting: 0.9994
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 169ms/step
# Frame 204: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0005
# Shoplifting: 0.9995
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 171ms/step
# Frame 206: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0003
# Shoplifting: 0.9997
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 167ms/step
# Frame 208: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0002
# Shoplifting: 0.9998
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 167ms/step
# Frame 210: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0001
# Shoplifting: 0.9999
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 170ms/step
# Frame 212: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0002
# Shoplifting: 0.9998
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 168ms/step
# Frame 214: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0001
# Shoplifting: 0.9998
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 167ms/step
# Frame 216: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0001
# Shoplifting: 0.9999
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 169ms/step
# Frame 218: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0001
# Shoplifting: 0.9999
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 168ms/step
# Frame 220: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0001
# Shoplifting: 0.9999
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 168ms/step
# Frame 222: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0001
# Shoplifting: 0.9999
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 168ms/step
# Frame 224: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0001
# Shoplifting: 0.9999
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 170ms/step
# Frame 226: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0001
# Shoplifting: 0.9999
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 173ms/step
# Frame 228: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 169ms/step
# Frame 230: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 167ms/step
# Frame 232: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 170ms/step
# Frame 234: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 174ms/step
# Frame 236: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 171ms/step
# Frame 238: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 172ms/step
# Frame 240: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 170ms/step
# Frame 242: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 169ms/step
# Frame 244: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 170ms/step
# Frame 246: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 167ms/step
# Frame 248: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0001
# Shoplifting: 0.9999
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 166ms/step
# Frame 250: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 173ms/step
# Frame 252: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 171ms/step
# Frame 254: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 169ms/step
# Frame 256: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 168ms/step
# Frame 258: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 172ms/step
# Frame 260: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 170ms/step
# Frame 262: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 168ms/step
# Frame 264: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 169ms/step
# Frame 266: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 170ms/step
# Frame 268: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 173ms/step
# Frame 270: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 169ms/step
# Frame 272: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 168ms/step
# Frame 274: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 172ms/step
# Frame 276: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 167ms/step
# Frame 278: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 171ms/step
# Frame 280: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 166ms/step
# Frame 282: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 170ms/step
# Frame 284: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 174ms/step
# Frame 286: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 185ms/step
# Frame 288: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0001
# Shoplifting: 0.9999
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 167ms/step
# Frame 290: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0001
# Shoplifting: 0.9999
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 166ms/step
# Frame 292: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0001
# Shoplifting: 0.9999
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 168ms/step
# Frame 294: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 171ms/step
# Frame 296: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 165ms/step
# Frame 298: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 173ms/step
# Frame 300: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 168ms/step
# Frame 302: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 167ms/step
# Frame 304: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 170ms/step
# Frame 306: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 166ms/step
# Frame 308: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 166ms/step
# Frame 310: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 166ms/step
# Frame 312: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 165ms/step
# Frame 314: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 169ms/step
# Frame 316: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 168ms/step
# Frame 318: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 166ms/step
# Frame 320: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 166ms/step
# Frame 322: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 169ms/step
# Frame 324: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 166ms/step
# Frame 326: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 167ms/step
# Frame 328: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 165ms/step
# Frame 330: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 168ms/step
# Frame 332: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 169ms/step
# Frame 334: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 168ms/step
# Frame 336: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 167ms/step
# Frame 338: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 167ms/step
# Frame 340: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 168ms/step
# Frame 342: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 170ms/step
# Frame 344: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 167ms/step
# Frame 346: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 167ms/step
# Frame 348: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 172ms/step
# Frame 350: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 169ms/step
# Frame 352: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 166ms/step
# Frame 354: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 181ms/step
# Frame 356: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 192ms/step
# Frame 358: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 197ms/step
# Frame 360: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 170ms/step
# Frame 362: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 171ms/step
# Frame 364: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 169ms/step
# Frame 366: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 0.9999
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 172ms/step
# Frame 368: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0001
# Shoplifting: 0.9999
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 167ms/step
# Frame 370: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0001
# Shoplifting: 0.9999
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 167ms/step
# Frame 372: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0001
# Shoplifting: 0.9999
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 167ms/step
# Frame 374: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0001
# Shoplifting: 0.9999
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 167ms/step
# Frame 376: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0001
# Shoplifting: 0.9999
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 201ms/step
# Frame 378: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0001
# Shoplifting: 0.9998
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 169ms/step
# Frame 380: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0001
# Shoplifting: 0.9998
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 169ms/step
# Frame 382: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0002
# Shoplifting: 0.9998
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 171ms/step
# Frame 384: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0001
# Shoplifting: 0.9999
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 170ms/step
# Frame 386: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 0.9999
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 166ms/step
# Frame 388: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 188ms/step
# Frame 390: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0000
# Shoplifting: 1.0000
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 167ms/step
# ...
# Shoplifting: 0.9976
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 166ms/step
# Frame 938: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0013
# Shoplifting: 0.9987
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 169ms/step
# Frame 940: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0012
# Shoplifting: 0.9987
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 169ms/step
# Frame 942: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0011
# Shoplifting: 0.9989
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 170ms/step
# Frame 944: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0009
# Shoplifting: 0.9991
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 170ms/step
# Frame 946: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0010
# Shoplifting: 0.9990
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 167ms/step
# Frame 948: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0010
# Shoplifting: 0.9989
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 168ms/step
# Frame 950: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0013
# Shoplifting: 0.9987
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 169ms/step
# Frame 952: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0018
# Shoplifting: 0.9982
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 172ms/step
# Frame 954: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0015
# Shoplifting: 0.9985
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 172ms/step
# Frame 956: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0016
# Shoplifting: 0.9984
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 171ms/step
# Frame 958: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0020
# Shoplifting: 0.9979
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 168ms/step
# Frame 960: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0024
# Shoplifting: 0.9976
# Abuse: 0.0000
# Arrest: 0.0000
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 170ms/step
# Frame 962: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0072
# Shoplifting: 0.9927
# Abuse: 0.0000
# Arrest: 0.0001
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 173ms/step
# Frame 964: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0070
# Shoplifting: 0.9929
# Abuse: 0.0000
# Arrest: 0.0001
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 169ms/step
# Frame 966: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0052
# Shoplifting: 0.9947
# Abuse: 0.0000
# Arrest: 0.0001
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 172ms/step
# Frame 968: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0050
# Shoplifting: 0.9949
# Abuse: 0.0000
# Arrest: 0.0001
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# 1/1 [==============================] - 0s 171ms/step
# Frame 970: Predicted Label: Shoplifting
# Probabilities:
# Fighting: 0.0042
# Shoplifting: 0.9957
# Abuse: 0.0000
# Arrest: 0.0001
# Shooting: 0.0000
# Robbery: 0.0000
# Explosion: 0.0000
# --------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 65
#      63 # Replace with your video file path
#      64 video_path = "/kaggle/input/video-test/Boxer Caught on CCTV - Knocks out 3 Men  Street Fight Self Defence Knockout Study.mp4"
# ---> 65 process_video(video_path)
#
# Cell In[3], line 52, in process_video(video_path)
#      49 # Process every other frame (adjust as needed)
#      50 if frame_count % 2 == 0:
#      51     # Predict action for this frame
# ---> 52     predicted_label, probabilities = predict_image(frame)
#      54     # Display or save results as needed
#      55     print(f"Frame {frame_count}: Predicted Label: {predicted_label}")
#
# Cell In[3], line 25, in predict_image(image)
#      22 image_lstm = image_gray.reshape((1,) + (-1, 1))
#      24 # Use the model to predict the category of the image
# ---> 25 prediction = model.predict([image_cnn, image_lstm])
#      27 # Extract probabilities for each class
#      28 probabilities = prediction[0]
#
# File /opt/conda/lib/python3.10/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/conda/lib/python3.10/site-packages/keras/engine/training.py:2317, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2308     except ValueError:
#    2309         warnings.warn(
#    2310             "Using Model.predict with MultiWorkerMirroredStrategy "
#    2311             "or TPUStrategy and AutoShardPolicy.FILE might lead to "
#    (...)
#    2314             stacklevel=2,
#    2315         )
# -> 2317 data_handler = data_adapter.get_data_handler(
#    2318     x=x,
#    2319     batch_size=batch_size,
#    2320     steps_per_epoch=steps,
#    2321     initial_epoch=0,
#    2322     epochs=1,
#    2323     max_queue_size=max_queue_size,
#    2324     workers=workers,
#    2325     use_multiprocessing=use_multiprocessing,
#    2326     model=self,
#    2327     steps_per_execution=self._steps_per_execution,
#    2328 )
#    2330 # Container that configures and calls `tf.keras.Callback`s.
#    2331 if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File /opt/conda/lib/python3.10/site-packages/keras/engine/data_adapter.py:1579, in get_data_handler(*args, **kwargs)
#    1577 if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1578     return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1579 return DataHandler(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/keras/engine/data_adapter.py:1259, in DataHandler.__init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1256     self._steps_per_execution = steps_per_execution
#    1258 adapter_cls = select_data_adapter(x, y)
# -> 1259 self._adapter = adapter_cls(
#    1260     x,
#    1261     y,
#    1262     batch_size=batch_size,
#    1263     steps=steps_per_epoch,
#    1264     epochs=epochs - initial_epoch,
#    1265     sample_weights=sample_weight,
#    1266     shuffle=shuffle,
#    1267     max_queue_size=max_queue_size,
#    1268     workers=workers,
#    1269     use_multiprocessing=use_multiprocessing,
#    1270     distribution_strategy=tf.distribute.get_strategy(),
#    1271     model=model,
#    1272 )
#    1274 strategy = tf.distribute.get_strategy()
#    1276 self._current_step = 0
#
# File /opt/conda/lib/python3.10/site-packages/keras/engine/data_adapter.py:306, in TensorLikeDataAdapter.__init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     299     return indices
#     301 # We prefetch a single element. Computing large permutations can take
#     302 # quite a while so we don't want to wait for prefetching over an epoch
#     303 # boundary to trigger the next permutation. On the other hand, too many
#     304 # simultaneous shuffles can contend on a hardware level and degrade all
#     305 # performance.
# --> 306 indices_dataset = indices_dataset.map(permutation).prefetch(1)
#     308 def slice_batch_indices(indices):
#     309     """Convert a Tensor of indices into a dataset of batched indices.
#     310
#     311     This step can be accomplished in several ways. The most natural is
#    (...)
#     323       A Dataset of batched indices.
#     324     """
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/data/ops/dataset_ops.py:2294, in DatasetV2.map(self, map_func, num_parallel_calls, deterministic, name)
#    2291   if deterministic is not None and not DEBUG_MODE:
#    2292     warnings.warn("The `deterministic` argument has no effect unless the "
#    2293                   "`num_parallel_calls` argument is specified.")
# -> 2294   return MapDataset(self, map_func, preserve_cardinality=True, name=name)
#    2295 else:
#    2296   return ParallelMapDataset(
#    2297       self,
#    2298       map_func,
#    (...)
#    2301       preserve_cardinality=True,
#    2302       name=name)
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/data/ops/dataset_ops.py:5499, in MapDataset.__init__(self, input_dataset, map_func, use_inter_op_parallelism, preserve_cardinality, use_legacy_function, name)
#    5497 self._use_inter_op_parallelism = use_inter_op_parallelism
#    5498 self._preserve_cardinality = preserve_cardinality
# -> 5499 self._map_func = structured_function.StructuredFunctionWrapper(
#    5500     map_func,
#    5501     self._transformation_name(),
#    5502     dataset=input_dataset,
#    5503     use_legacy_function=use_legacy_function)
#    5504 self._name = name
#    5505 variant_tensor = gen_dataset_ops.map_dataset(
#    5506     input_dataset._variant_tensor,  # pylint: disable=protected-access
#    5507     self._map_func.function.captured_inputs,
#    (...)
#    5510     preserve_cardinality=self._preserve_cardinality,
#    5511     **self._common_args)
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/data/ops/structured_function.py:263, in StructuredFunctionWrapper.__init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#     256       warnings.warn(
#     257           "Even though the `tf.config.experimental_run_functions_eagerly` "
#     258           "option is set, this option does not apply to tf.data functions. "
#     259           "To force eager execution of tf.data functions, please use "
#     260           "`tf.data.experimental.enable_debug_mode()`.")
#     261     fn_factory = trace_tf_function(defun_kwargs)
# --> 263 self._function = fn_factory()
#     264 # There is no graph to add in eager mode.
#     265 add_to_graph &= not context.executing_eagerly()
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:226, in TracingCompiler.get_concrete_function(self, *args, **kwargs)
#     217 def get_concrete_function(self, *args, **kwargs):
#     218   """Returns a `ConcreteFunction` specialized to inputs and execution context.
#     219
#     220   Args:
#    (...)
#     224       `tf.Tensor` or `tf.TensorSpec`.
#     225   """
# --> 226   concrete_function = self._get_concrete_function_garbage_collected(
#     227       *args, **kwargs)
#     228   concrete_function._garbage_collector.release()  # pylint: disable=protected-access
#     229   return concrete_function
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:192, in TracingCompiler._get_concrete_function_garbage_collected(self, *args, **kwargs)
#     189   self._function_spec.validate_inputs_with_signature(args, kwargs)
#     191 with self._lock:
# --> 192   concrete_function, _ = self._maybe_define_concrete_function(args, kwargs)
#     193   seen_names = set()
#     194   captured = object_identity.ObjectIdentitySet(
#     195       concrete_function.graph.internal_captures)
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:157, in TracingCompiler._maybe_define_concrete_function(self, args, kwargs)
#     154   args = self.input_signature
#     155   kwargs = {}
# --> 157 return self._maybe_define_function(args, kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:360, in TracingCompiler._maybe_define_function(self, args, kwargs)
#     357   # Only get placeholders for arguments, not captures
#     358   args, kwargs = generalized_func_key._placeholder_value()  # pylint: disable=protected-access
# --> 360 concrete_function = self._create_concrete_function(args, kwargs)
#     362 graph_capture_container = concrete_function.graph._capture_func_lib  # pylint: disable=protected-access
#     363 # Maintain the list of all captures
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py:284, in TracingCompiler._create_concrete_function(self, args, kwargs)
#     279 missing_arg_names = [
#     280     "%s_%d" % (arg, i) for i, arg in enumerate(missing_arg_names)
#     281 ]
#     282 arg_names = base_arg_names + missing_arg_names
#     283 concrete_function = monomorphic_function.ConcreteFunction(
# --> 284     func_graph_module.func_graph_from_py_func(
#     285         self._name,
#     286         self._python_function,
#     287         args,
#     288         kwargs,
#     289         None,
#     290         autograph=self._autograph,
#     291         autograph_options=self._autograph_options,
#     292         arg_names=arg_names,
#     293         capture_by_value=self._capture_by_value),
#     294     self._function_attributes,
#     295     spec=self.function_spec,
#     296     # Tell the ConcreteFunction to clean up its graph once it goes out of
#     297     # scope. This is not the default behavior since it gets used in some
#     298     # places (like Keras) where the FuncGraph lives longer than the
#     299     # ConcreteFunction.
#     300     shared_func_graph=False)
#     301 return concrete_function
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/framework/func_graph.py:1186, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, acd_record_initial_resource_uses)
#    1184   args = signature
#    1185   kwargs = {}
# -> 1186 func_args = _get_defun_inputs_from_args(args, arg_names)
#    1187 func_kwargs = _get_defun_inputs_from_kwargs(kwargs)
#    1189 for arg in nest.flatten([func_args, func_kwargs], expand_composites=True):
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/framework/func_graph.py:1465, in _get_defun_inputs_from_args(args, names)
#    1463 def _get_defun_inputs_from_args(args, names):
#    1464   """Maps Python function positional args to graph-construction inputs."""
# -> 1465   return _get_defun_inputs(args, names, structured_args=args)
#
# File /opt/conda/lib/python3.10/site-packages/tensorflow/python/framework/func_graph.py:1499, in _get_defun_inputs(args, names, structured_args)
#    1496 for arg_value, name in zip(args, names):
#    1497   for val in composite_tensor_utils.flatten_with_variables_or_variable_specs(
#    1498       arg_value):
# -> 1499     function_inputs.append(_get_defun_input(val, name))
#    1500 return nest.pack_sequence_as(
#    1501     structured_args,
#    1502     nest.flatten(function_inputs, expand_composites=True),
#    1503     expand_composites=True)
#
# KeyboardInterrupt:

# %%
import cv2
import numpy as np
from keras.models import load_model

# Assuming you have already defined categories_labels and labels_categories
categories_labels = {'Fighting': 0, 'Shoplifting': 1, 'Abuse': 2, 'Arrest': 3, 'Shooting': 4, 'Robbery': 5, 'Explosion': 6}
labels_categories = {v: k for k, v in categories_labels.items()}  # reverse dictionary for label lookup

# Load the trained model
model = load_model('/kaggle/input/model2/CNN_LSTM (1).h5')

def detect_and_classify_anomaly(image_path, anomaly_threshold=0.5):
    # Load the image
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

    # Resize the image
    image = cv2.resize(image, (50, 50))

    # Reshape the image to 4D array for CNN and LSTM input
    image_cnn = image.reshape((1,) + image.shape + (1,))
    image_lstm = image.reshape((1,) + (-1, 1))

    # Use the model to predict the category of the image
    prediction = model.predict([image_cnn, image_lstm])

    # Get the highest probability and corresponding label
    max_prob = np.max(prediction)
    label_index = np.argmax(prediction)
    label = labels_categories[label_index]

    # Check if it's an anomaly based on the threshold
    if max_prob > anomaly_threshold:
        return f"Anomaly Detected: {label}"
    else:
        return "No Anomaly Detected"

# Test for anomaly detection and classification
image_path = "/kaggle/input/cctv-image/cctv3.jpeg"  # Replace with your image path
result = detect_and_classify_anomaly(image_path, anomaly_threshold=0.5)

print(result)
# Out:
# 1/1 [==============================] - 1s 1s/step
# Anomaly Detected: Robbery

# %%
#============================= this code with any image*.gif

import cv2
import numpy as np
import os
from keras.models import load_model
from PIL import Image

categories_labels = {'Fighting': 0, 'Shoplifting': 1, 'Abuse': 2, 'Arrest': 3, 'Shooting': 4, 'Robbery': 5, 'Explosion': 6}
labels_categories = {v: k for k, v in categories_labels.items()}  # reverse dictionary for label lookup

# Load the trained model
model = load_model('/kaggle/input/model2/CNN_LSTM (1).h5')

def predict_image(image):
    # Resize the image
    image = cv2.resize(image, (50, 50))

    # Reshape the image to 4D array for CNN and LSTM input
    image_cnn = image.reshape((1,) + image.shape + (1,))
    image_lstm = image.reshape((1,) + (-1, 1))

    # Use the model to predict the category of the image
    prediction = model.predict([image_cnn, image_lstm])

    # Find the category with the highest probability
    label = np.argmax(prediction)

    # Return the name of the category
    return labels_categories[label]

def extract_and_predict(gif_path):
    # Open the gif image
    gif = Image.open(gif_path)

    # Extract all frames from the gif
    frames = []
    try:
        while True:
            gif.seek(gif.tell() + 1)
            frames.append(np.array(gif.convert('L')))  # Convert image to grayscale
    except EOFError:
        pass  # end of sequence

    # Predict the category of each frame and save it in a new directory
    new_dir = 'predicted_images'
    os.makedirs(new_dir, exist_ok=True)
    last_category = None  # variable to keep track of the last predicted category
    for i, frame in enumerate(frames):
        category = predict_image(frame)
        if category != last_category:  # only print the category if it's different from the last one
            print('Frame', i, 'Category:', category)
        last_category = category  # update the last predicted category
        cv2.imwrite(os.path.join(new_dir, f'{category}_{i}.png'), frame)

# Test the function
gif_path = "/kaggle/input/video-test/Boxer Caught on CCTV - Knocks out 3 Men  Street Fight Self Defence Knockout Study.mp4"  # Replace with your gif path
extract_and_predict(gif_path)

#0 to 208 Robbery, then 209-210 arrest, then ..........
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# Cell In[1], line 58
#      56 # Test the function
#      57 gif_path = "/kaggle/input/video-test/Boxer Caught on CCTV - Knocks out 3 Men  Street Fight Self Defence Knockout Study.mp4"  # Replace with your gif path
# ---> 58 extract_and_predict(gif_path)
#      60 #0 to 208 Robbery, then 209-210 arrest, then ..........
#
# Cell In[1], line 34, in extract_and_predict(gif_path)
#      32 def extract_and_predict(gif_path):
#      33     # Open the gif image
# ---> 34     gif = Image.open(gif_path)
#      36     # Extract all frames from the gif
#      37     frames = []
#
# File /opt/conda/lib/python3.10/site-packages/PIL/Image.py:3298, in open(fp, mode, formats)
#    3296     warnings.warn(message)
#    3297 msg = "cannot identify image file %r" % (filename if filename else fp)
# -> 3298 raise UnidentifiedImageError(msg)
#
# UnidentifiedImageError: cannot identify image file '/kaggle/input/video-test/Boxer Caught on CCTV - Knocks out 3 Men  Street Fight Self Defence Knockout Study.mp4'
